# %% [markdown]
#    # MLP in Pytorch

# %% [markdown]
# **Partea 1** Sa se creeze si antreneze un model de tip MLP, folosind setul de date MNIST. Arhitecura modelului - numarul de neuroni in straturile ascunse - va fi data ca o lista de intregi, de exemplu:
# `architecture=[100, 40, 20]` reprezinta o retea MLP cu 3 straturi ascunse, cu cate 100, 40, respectiv 20 de neuroni in straturile ascunse. Se va transmite, de asemenea functia de activare folosita pentru straturile ascunse. Se vor tipari (pe masura ce se antreneaza) si reprezenta grafic (la final de instruire): loss pe setul de antrenare, loss si acuratete pe setul de testare pentru fiecare de instruire.
#
# **Partea a doua**. Automatizati procesul de cautare pentru arhitectura retelei si learnign rate:
# 1. Definiti o lista de learnign rates candidate, e.g. lrs = [1e-2, 1e-3, 1e-4]
# 1. Definiti o lista de arhitecturi candidate, e.g. architectures=[[100, 40, 20], [200, 40]]
# 1. Iterati peste toate combinatiile de learnign rate si arhitecturi; antrenati cate un model pe fiecare combinatie in parte, testati pe setul de testare. Retineti acea combinatie (lr, architecture) care duce la acuratete maxima pe setul de testare.
# 1. Optional, puteti adauga alti hiperparametri pentru modele: valoarea coeficientului de momentum si weight decay pentru SGD, numarul de epoci.
#
# Note:
# 1. Pentru adaugarea de module la structura retelei se poate folosi clasa [torch.nn.Sequential](https://pytorch.org/docs/stable/generated/torch.nn.Sequential.html).
# 1. Functiile de activare se pot alege din cele [definite in Pytorch].(https://pytorch.org/docs/stable/nn.html#non-linear-activations-weighted-sum-nonlinearity)

# %% [markdown]
# Termen de predare: 11 ian 2025, 08:00
#
# Se vor folosi type annotations pentru variabile, parametrii tuturor funcțiilor, tipuri de retur. Tema se noteaza doar in prezenta studentului; rezolvarile sunt individuale.
#
# Se acordă doua puncte din oficiu. Fișierul va fi denumit tema5_ia_nume_prenume.ipynb. Verificați înainte de trimitere faptul ca execuția celulelor de sus în jos funcționează corespunzător.

# %% [markdown]
# ## Setup

# %%
# !pip install torch-summary
# Out:
# Requirement already satisfied: torch-summary in ./.venv/lib/python3.12/site-packages (1.4.5)
#
# [notice] A new release of pip is available: 24.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from torch import nn
import torchvision
from torch.utils.data import DataLoader
from typing import List, Tuple
import matplotlib.pyplot as plt
from torchsummary import summary
from typing import Tuple

# %%
device: str = 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# ## Setul de date

# %%
batch_size : int = 32

# %%
# transformarea ToTensor transforma datele in tensori PyTorch si scaleaza datele
# in intervalul [0, 1]
# doc: https://pytorch.org/vision/main/generated/torchvision.transforms.ToTensor.html
transform = torchvision.transforms.Compose([torchvision.transforms.ToTensor()])

# setul de date MNIST este pus la dispozitie prin pachetul torchvision
# doc: https://pytorch.org/vision/stable/generated/torchvision.datasets.MNIST.html#torchvision.datasets.MNIST
train_dataset = torchvision.datasets.MNIST(
    root="data", train=True, transform=transform, download=True
)

test_dataset = torchvision.datasets.MNIST(
    root="data", train=False, transform=transform, download=True
)

# %%
# Loaders for batches
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, num_workers=0
)

test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False, num_workers=0
)

# %% [markdown]
# ## Definirea MLP

# %% [markdown]
# ### Modelul

# %%
class MLP_Dynamic(nn.Module):
    """
    MLP model with dynamic architecture
    """
    def __init__(self, 
                 input_size: int = 784, 
                 hidden_architecture: List[int] = [100, 40, 20],
                 activation_fx : torch.nn.modules.activation = torch.nn.Tanh(),
                 n_classes: int = 10):
        """
        Initializes MLP model with:
        :param input_size: input size for current nn
        :hidden_architecture: A list of ints of length equal to the number of hidden layers and each element equal to the number of neurons in that layer
        :activation_fx: the activation function used for all hidden layers
        :n_classes: output size
        """
        super().__init__()
        # Define linear layers list (will have linear layers, each followed by activation fx)
        linear_layers = []
        ... # Create nn.Linear layers based on hidden_architecture and input_size, add activation functions
        self.hidden_layers = nn.Sequential(*linear_layers)
        self.output_lauer = ...
        
    def forward(self, x):
        # Transform MNIST image of size 1x28x28 to 1D tensor of size 784
        x = ...
        
        # Propagate through flow defined by self.hidden_layers
        y = ...
        
        # propagare spre stratul de iesire
        z = self.output(y)
        return z

# %% [markdown]
# ### Functii antrenare, testare

# %%
@torch.no_grad()
def test(model: nn.Module, 
         criterion: nn.CrossEntropyLoss, 
         loader: torch.utils.data.DataLoader, 
         device: torch.device) -> Tuple[float, float]:
    """
    Test the given model on data provided by :param test_loader:
    
    :param model: the modeul used for inference
    :param criterion: loss function
    :param loader: the dataloader used to fetch the data
    :param device: the device used to run the model
    
    :return: accuracy and loss on the test data.
    """
    # se trece modelul in mod de evaluare
    model.eval()
    # acumulatori de performanta
    accuracy : float = 0
    test_loss : float = 0
    
    for x, y in loader:
        x, y = x.to(device), y.to(device)
        y_hat = ... # trecerea batch-ului prin model
        # loss-ul calculat e medie peste batch; pt loss-ul total trebuie sa renuntam la mediere
        loss = ...
        test_loss += loss
        # preia clasele prezise si calculeaza acuratetea
        _, predicted = ...
        accuracy += ...
        
        
    return accuracy, test_loss

# %%
def train(model: nn.Module, 
          epochs: int, 
          criterion: nn.CrossEntropyLoss,
          optimizer: torch.optim.SGD,
          train_loader: torch.utils.data.DataLoader, 
          test_loader: torch.utils.data.DataLoader,
          device: torch.device) -> None:
    """
    Train a model on the given :param train_loader: loader, for :param epochs: epochs, on the specified
    :param device:, using :param optimizer: optimizer.
    At the end of the training will plot accuracy and loss for training and test data.
    """
    train_losses : List[float] = []
    test_accuracies : List[float] = []
    test_losses : List[float] = []
    test_accuracy_untrained, test_loss_untrained = test(model, criterion, test_loader, device)
    print(f'On untrained model, test set: acc={test_accuracy_untrained*100:.2f}, loss={test_loss_untrained:.4f}')
    for epoch in range(1, epochs+1):
        model.train()
        running_train_loss : float = 0
        for x, y in train_loader:
            # transfer de date catre device
            x, y = x.to(device), y.to(device)
            
            # predictie 
            y_hat : torch.Tensor = ...
            
            # calcul valoare de eroare
            loss : float = ...
            
            # eroarea loss e media peste datele din minibatch, deci trebuie sa inmultim ca numarul
            # de date din batch pentru a avea loss-ul total pe minibatch
            running_train_loss += ...
            
            # resetare gradienti, pentru a evita acumularea peste gradientii precedenti
            ...
            
            # calcul gradienti
            ...
            
            # se modifica ponderile curente
            ...
        
        # adaugati costurile in listele de losses, calculati acuratetile
        train_losses.append(...)
        test_accuracy, test_loss = ...
        print(f'Epoch {epoch}/{epochs}, train set: loss={train_losses[-1]:.4f}')
        print(f'Epoch {epoch}/{epochs}, test set: acc={test_accuracy*100:.2f}%, loss={test_loss:.4f}')
        test_losses.append(...)
        test_accuracies.append(...)
        
    # Creati un singur plot care sa afiseze costurile de antrenare si testare
    ...
    plt.title('Loss curves')
    plt.plot(...)
    plt.plot(...)
    plt.show()
    
    # Creati un plot care sa afiseze acuratetile
    ...

# %% [markdown]
# ## Antrenarea modelului - partea 1

# %%
# Define model (the other parameters are left as default)
model = MLP_Dynamic(activation_fx=torch.nn.modules.activation.Tanh())
# Move model to device
model.to(device)
# Out:
# MLP_Dynamic(
#   (hidden_layers): Sequential(
#     (0): Linear(in_features=784, out_features=100, bias=True)
#     (1): Tanh()
#     (2): Linear(in_features=100, out_features=40, bias=True)
#     (3): Tanh()
#     (4): Linear(in_features=40, out_features=20, bias=True)
#     (5): Tanh()
#   )
#   (output): Linear(in_features=20, out_features=10, bias=True)
# )

# %%
summary(model, device=device)

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# Alegeti hiperparametri
epochs : int = ..
lr : float = ..
momentum : float = ..
weight_decay : float = ...

criterion = ...
optimizer = ...

# %%
train(model, epochs, criterion, optimizer, train_loader, test_loader, device)
# Out:
# On untrained model, test set: acc=10.70, loss=2.3122
# Epoch 1/50, train set: loss=0.9441
# Epoch 1/50, test set: acc=89.23%, loss=0.3850
# Epoch 2/50, train set: loss=0.3315
# Epoch 2/50, test set: acc=92.09%, loss=0.2772
# Epoch 3/50, train set: loss=0.2423
# Epoch 3/50, test set: acc=93.93%, loss=0.2128
# Epoch 4/50, train set: loss=0.1882
# Epoch 4/50, test set: acc=95.06%, loss=0.1724
# Epoch 5/50, train set: loss=0.1576
# Epoch 5/50, test set: acc=95.44%, loss=0.1501
# Epoch 6/50, train set: loss=0.1365
# Epoch 6/50, test set: acc=95.85%, loss=0.1357
# Epoch 7/50, train set: loss=0.1222
# Epoch 7/50, test set: acc=95.82%, loss=0.1351
# Epoch 8/50, train set: loss=0.1107
# Epoch 8/50, test set: acc=96.47%, loss=0.1154
# Epoch 9/50, train set: loss=0.1002
# Epoch 9/50, test set: acc=96.56%, loss=0.1136
# Epoch 10/50, train set: loss=0.0936
# Epoch 10/50, test set: acc=96.84%, loss=0.1060
# Epoch 11/50, train set: loss=0.0865
# Epoch 11/50, test set: acc=96.92%, loss=0.1033
# Epoch 12/50, train set: loss=0.0834
# Epoch 12/50, test set: acc=96.78%, loss=0.1059
# Epoch 13/50, train set: loss=0.0768
# Epoch 13/50, test set: acc=97.14%, loss=0.0942
# Epoch 14/50, train set: loss=0.0739
# Epoch 14/50, test set: acc=97.19%, loss=0.0937
# Epoch 15/50, train set: loss=0.0706
# Epoch 15/50, test set: acc=97.00%, loss=0.0984
# Epoch 16/50, train set: loss=0.0673
# Epoch 16/50, test set: acc=96.82%, loss=0.0999
# Epoch 17/50, train set: loss=0.0653
# Epoch 17/50, test set: acc=97.19%, loss=0.0923
# Epoch 18/50, train set: loss=0.0637
# Epoch 18/50, test set: acc=97.27%, loss=0.0905
# Epoch 19/50, train set: loss=0.0604
# Epoch 19/50, test set: acc=97.20%, loss=0.0934
# Epoch 20/50, train set: loss=0.0588
# Epoch 20/50, test set: acc=97.08%, loss=0.0936
# Epoch 21/50, train set: loss=0.0567
# Epoch 21/50, test set: acc=97.50%, loss=0.0838
# Epoch 22/50, train set: loss=0.0552
# Epoch 22/50, test set: acc=97.45%, loss=0.0865
# Epoch 23/50, train set: loss=0.0534
# Epoch 23/50, test set: acc=97.27%, loss=0.0868
# Epoch 24/50, train set: loss=0.0530
# Epoch 24/50, test set: acc=97.28%, loss=0.0861
# Epoch 25/50, train set: loss=0.0518
# Epoch 25/50, test set: acc=97.36%, loss=0.0849
# Epoch 26/50, train set: loss=0.0499
# Epoch 26/50, test set: acc=97.41%, loss=0.0838
# Epoch 27/50, train set: loss=0.0498
# Epoch 27/50, test set: acc=97.61%, loss=0.0798
# Epoch 28/50, train set: loss=0.0472
# Epoch 28/50, test set: acc=97.17%, loss=0.0869
# Epoch 29/50, train set: loss=0.0475
# Epoch 29/50, test set: acc=97.12%, loss=0.0958
# Epoch 30/50, train set: loss=0.0472
# Epoch 30/50, test set: acc=97.36%, loss=0.0832
# Epoch 31/50, train set: loss=0.0459
# Epoch 31/50, test set: acc=97.28%, loss=0.0849
# Epoch 32/50, train set: loss=0.0459
# Epoch 32/50, test set: acc=97.47%, loss=0.0799
# Epoch 33/50, train set: loss=0.0455
# Epoch 33/50, test set: acc=97.59%, loss=0.0780
# Epoch 34/50, train set: loss=0.0441
# Epoch 34/50, test set: acc=97.58%, loss=0.0793
# Epoch 35/50, train set: loss=0.0441
# Epoch 35/50, test set: acc=97.59%, loss=0.0826
# Epoch 36/50, train set: loss=0.0438
# Epoch 36/50, test set: acc=97.55%, loss=0.0795
# Epoch 37/50, train set: loss=0.0423
# Epoch 37/50, test set: acc=97.64%, loss=0.0762
# Epoch 38/50, train set: loss=0.0421
# Epoch 38/50, test set: acc=97.58%, loss=0.0784
# Epoch 39/50, train set: loss=0.0411
# Epoch 39/50, test set: acc=97.39%, loss=0.0850
# Epoch 40/50, train set: loss=0.0408
# Epoch 40/50, test set: acc=97.56%, loss=0.0791
# Epoch 41/50, train set: loss=0.0401
# Epoch 41/50, test set: acc=97.21%, loss=0.0886
# Epoch 42/50, train set: loss=0.0412
# Epoch 42/50, test set: acc=97.59%, loss=0.0792
# Epoch 43/50, train set: loss=0.0401
# Epoch 43/50, test set: acc=97.58%, loss=0.0773
# Epoch 44/50, train set: loss=0.0402
# Epoch 44/50, test set: acc=97.51%, loss=0.0808
# Epoch 45/50, train set: loss=0.0408
# Epoch 45/50, test set: acc=97.40%, loss=0.0844
# Epoch 46/50, train set: loss=0.0387
# Epoch 46/50, test set: acc=97.49%, loss=0.0807
# Epoch 47/50, train set: loss=0.0385
# Epoch 47/50, test set: acc=97.63%, loss=0.0775
# Epoch 48/50, train set: loss=0.0376
# Epoch 48/50, test set: acc=97.76%, loss=0.0739
# Epoch 49/50, train set: loss=0.0388
# Epoch 49/50, test set: acc=97.46%, loss=0.0821
# Epoch 50/50, train set: loss=0.0385
# Epoch 50/50, test set: acc=97.62%, loss=0.0745

# %% [markdown]
# ## Antrenarea modelului - Partea 2

# %%
import itertools

# %%
candidate_lrs : List[float] = [1e-2, 1e-3, 1e-4]
candidate_architectures : List[List[int]] = [[100, 40, 20], [200, 40]]

# %%
epochs : int = ...
momentum : float = ..
weight_decay : float = ..
criterion = ..

max_accuracy : float = ..
best_performing_params: Tuple[int, int] = None # Tuple of lr, candidate_architecture
best_performing_model : MLP_Dynamic = None

# %%
# Scrieti antrenarea retelelor pe baza produsului cartezian dintre multimea candidate_lrs si candidate_architectures
# Fiecare antrenare va afisa log-urile similar cu antrenarile anteriore
# Pastrati modelul cu acuratete maxima si care sunt valorile pentru learning rate si arhitectura cu care a fost obtinut
...
# Out:
# Training: lr=0.01, arhitecture=[100, 40, 20]
# On untrained model, test set: acc=4.96, loss=2.3210
# Epoch 1/30, train set: loss=0.9929
# Epoch 1/30, test set: acc=88.97%, loss=0.4049
# Epoch 2/30, train set: loss=0.3368
# Epoch 2/30, test set: acc=92.39%, loss=0.2711
# Epoch 3/30, train set: loss=0.2422
# Epoch 3/30, test set: acc=94.10%, loss=0.2115
# Epoch 4/30, train set: loss=0.1902
# Epoch 4/30, test set: acc=94.96%, loss=0.1743
# Epoch 5/30, train set: loss=0.1588
# Epoch 5/30, test set: acc=95.74%, loss=0.1476
# Epoch 6/30, train set: loss=0.1382
# Epoch 6/30, test set: acc=95.76%, loss=0.1474
# Epoch 7/30, train set: loss=0.1237
# Epoch 7/30, test set: acc=96.50%, loss=0.1226
# Epoch 8/30, train set: loss=0.1116
# Epoch 8/30, test set: acc=96.49%, loss=0.1161
# Epoch 9/30, train set: loss=0.1017
# Epoch 9/30, test set: acc=96.77%, loss=0.1081
# Epoch 10/30, train set: loss=0.0950
# Epoch 10/30, test set: acc=96.93%, loss=0.1002
# Epoch 11/30, train set: loss=0.0879
# Epoch 11/30, test set: acc=96.80%, loss=0.1065
# Epoch 12/30, train set: loss=0.0844
# Epoch 12/30, test set: acc=97.24%, loss=0.0956
# Epoch 13/30, train set: loss=0.0794
# Epoch 13/30, test set: acc=97.25%, loss=0.0966
# Epoch 14/30, train set: loss=0.0741
# Epoch 14/30, test set: acc=97.21%, loss=0.0946
# Epoch 15/30, train set: loss=0.0711
# Epoch 15/30, test set: acc=97.42%, loss=0.0899
# Epoch 16/30, train set: loss=0.0681
# Epoch 16/30, test set: acc=97.55%, loss=0.0847
# Epoch 17/30, train set: loss=0.0658
# Epoch 17/30, test set: acc=97.31%, loss=0.0896
# Epoch 18/30, train set: loss=0.0625
# Epoch 18/30, test set: acc=97.38%, loss=0.0871
# Epoch 19/30, train set: loss=0.0613
# Epoch 19/30, test set: acc=97.26%, loss=0.0867
# Epoch 20/30, train set: loss=0.0594
# Epoch 20/30, test set: acc=96.77%, loss=0.0998
# Epoch 21/30, train set: loss=0.0576
# Epoch 21/30, test set: acc=97.56%, loss=0.0811
# Epoch 22/30, train set: loss=0.0558
# Epoch 22/30, test set: acc=97.49%, loss=0.0830
# Epoch 23/30, train set: loss=0.0544
# Epoch 23/30, test set: acc=97.50%, loss=0.0831
# Epoch 24/30, train set: loss=0.0528
# Epoch 24/30, test set: acc=97.41%, loss=0.0827
# Epoch 25/30, train set: loss=0.0523
# Epoch 25/30, test set: acc=97.45%, loss=0.0819
# Epoch 26/30, train set: loss=0.0506
# Epoch 26/30, test set: acc=97.63%, loss=0.0789
# Epoch 27/30, train set: loss=0.0494
# Epoch 27/30, test set: acc=97.42%, loss=0.0826
# Epoch 28/30, train set: loss=0.0498
# Epoch 28/30, test set: acc=97.59%, loss=0.0829
# Epoch 29/30, train set: loss=0.0478
# Epoch 29/30, test set: acc=97.74%, loss=0.0773
# Epoch 30/30, train set: loss=0.0470
# Epoch 30/30, test set: acc=97.82%, loss=0.0768
# Training: lr=0.01, arhitecture=[200, 40]
# On untrained model, test set: acc=8.44, loss=2.3151
# Epoch 1/30, train set: loss=0.6952
# Epoch 1/30, test set: acc=91.18%, loss=0.3223
# Epoch 2/30, train set: loss=0.3011
# Epoch 2/30, test set: acc=92.33%, loss=0.2684
# Epoch 3/30, train set: loss=0.2553
# Epoch 3/30, test set: acc=93.42%, loss=0.2320
# Epoch 4/30, train set: loss=0.2239
# Epoch 4/30, test set: acc=94.04%, loss=0.2083
# Epoch 5/30, train set: loss=0.1975
# Epoch 5/30, test set: acc=94.59%, loss=0.1867
# Epoch 6/30, train set: loss=0.1762
# Epoch 6/30, test set: acc=95.34%, loss=0.1662
# Epoch 7/30, train set: loss=0.1589
# Epoch 7/30, test set: acc=95.42%, loss=0.1551
# Epoch 8/30, train set: loss=0.1458
# Epoch 8/30, test set: acc=95.72%, loss=0.1455
# Epoch 9/30, train set: loss=0.1343
# Epoch 9/30, test set: acc=96.13%, loss=0.1352
# Epoch 10/30, train set: loss=0.1255
# Epoch 10/30, test set: acc=96.19%, loss=0.1306
# Epoch 11/30, train set: loss=0.1176
# Epoch 11/30, test set: acc=96.39%, loss=0.1213
# Epoch 12/30, train set: loss=0.1102
# Epoch 12/30, test set: acc=96.61%, loss=0.1161
# Epoch 13/30, train set: loss=0.1049
# Epoch 13/30, test set: acc=96.61%, loss=0.1134
# Epoch 14/30, train set: loss=0.0988
# Epoch 14/30, test set: acc=96.85%, loss=0.1073
# Epoch 15/30, train set: loss=0.0943
# Epoch 15/30, test set: acc=96.91%, loss=0.1043
# Epoch 16/30, train set: loss=0.0909
# Epoch 16/30, test set: acc=96.91%, loss=0.1045
# Epoch 17/30, train set: loss=0.0878
# Epoch 17/30, test set: acc=97.03%, loss=0.0998
# Epoch 18/30, train set: loss=0.0839
# Epoch 18/30, test set: acc=97.14%, loss=0.0983
# Epoch 19/30, train set: loss=0.0815
# Epoch 19/30, test set: acc=97.11%, loss=0.0995
# Epoch 20/30, train set: loss=0.0790
# Epoch 20/30, test set: acc=96.95%, loss=0.1022
# Epoch 21/30, train set: loss=0.0766
# Epoch 21/30, test set: acc=97.35%, loss=0.0918
# Epoch 22/30, train set: loss=0.0743
# Epoch 22/30, test set: acc=97.30%, loss=0.0919
# Epoch 23/30, train set: loss=0.0729
# Epoch 23/30, test set: acc=97.54%, loss=0.0871
# Epoch 24/30, train set: loss=0.0708
# Epoch 24/30, test set: acc=97.52%, loss=0.0885
# Epoch 25/30, train set: loss=0.0696
# Epoch 25/30, test set: acc=97.46%, loss=0.0876
# Epoch 26/30, train set: loss=0.0675
# Epoch 26/30, test set: acc=97.59%, loss=0.0841
# Epoch 27/30, train set: loss=0.0667
# Epoch 27/30, test set: acc=97.54%, loss=0.0840
# Epoch 28/30, train set: loss=0.0646
# Epoch 28/30, test set: acc=97.72%, loss=0.0798
# Epoch 29/30, train set: loss=0.0640
# Epoch 29/30, test set: acc=97.54%, loss=0.0816
# Epoch 30/30, train set: loss=0.0626
# Epoch 30/30, test set: acc=97.71%, loss=0.0789
# Training: lr=0.001, arhitecture=[100, 40, 20]
# On untrained model, test set: acc=5.97, loss=2.3121
# Epoch 1/30, train set: loss=2.1755
# Epoch 1/30, test set: acc=53.54%, loss=1.9347
# Epoch 2/30, train set: loss=1.5609
# Epoch 2/30, test set: acc=69.47%, loss=1.2166
# Epoch 3/30, train set: loss=1.0031
# Epoch 3/30, test set: acc=80.07%, loss=0.8272
# Epoch 4/30, train set: loss=0.7419
# Epoch 4/30, test set: acc=83.72%, loss=0.6559
# Epoch 5/30, train set: loss=0.6144
# Epoch 5/30, test set: acc=85.75%, loss=0.5595
# Epoch 6/30, train set: loss=0.5352
# Epoch 6/30, test set: acc=87.25%, loss=0.4935
# Epoch 7/30, train set: loss=0.4802
# Epoch 7/30, test set: acc=88.20%, loss=0.4474
# Epoch 8/30, train set: loss=0.4394
# Epoch 8/30, test set: acc=88.87%, loss=0.4128
# Epoch 9/30, train set: loss=0.4081
# Epoch 9/30, test set: acc=89.27%, loss=0.3862
# Epoch 10/30, train set: loss=0.3829
# Epoch 10/30, test set: acc=89.98%, loss=0.3632
# Epoch 11/30, train set: loss=0.3619
# Epoch 11/30, test set: acc=90.50%, loss=0.3451
# Epoch 12/30, train set: loss=0.3440
# Epoch 12/30, test set: acc=90.92%, loss=0.3285
# Epoch 13/30, train set: loss=0.3286
# Epoch 13/30, test set: acc=91.30%, loss=0.3149
# Epoch 14/30, train set: loss=0.3147
# Epoch 14/30, test set: acc=91.52%, loss=0.3029
# Epoch 15/30, train set: loss=0.3022
# Epoch 15/30, test set: acc=91.91%, loss=0.2915
# Epoch 16/30, train set: loss=0.2909
# Epoch 16/30, test set: acc=92.11%, loss=0.2820
# Epoch 17/30, train set: loss=0.2801
# Epoch 17/30, test set: acc=92.31%, loss=0.2718
# Epoch 18/30, train set: loss=0.2702
# Epoch 18/30, test set: acc=92.79%, loss=0.2630
# Epoch 19/30, train set: loss=0.2606
# Epoch 19/30, test set: acc=92.92%, loss=0.2554
# Epoch 20/30, train set: loss=0.2521
# Epoch 20/30, test set: acc=93.18%, loss=0.2466
# Epoch 21/30, train set: loss=0.2438
# Epoch 21/30, test set: acc=93.29%, loss=0.2390
# Epoch 22/30, train set: loss=0.2358
# Epoch 22/30, test set: acc=93.68%, loss=0.2313
# Epoch 23/30, train set: loss=0.2286
# Epoch 23/30, test set: acc=93.67%, loss=0.2250
# Epoch 24/30, train set: loss=0.2216
# Epoch 24/30, test set: acc=93.92%, loss=0.2185
# Epoch 25/30, train set: loss=0.2153
# Epoch 25/30, test set: acc=94.12%, loss=0.2139
# Epoch 26/30, train set: loss=0.2091
# Epoch 26/30, test set: acc=94.16%, loss=0.2079
# Epoch 27/30, train set: loss=0.2035
# Epoch 27/30, test set: acc=94.31%, loss=0.2023
# Epoch 28/30, train set: loss=0.1982
# Epoch 28/30, test set: acc=94.50%, loss=0.1976
# Epoch 29/30, train set: loss=0.1931
# Epoch 29/30, test set: acc=94.55%, loss=0.1931
# Epoch 30/30, train set: loss=0.1883
# Epoch 30/30, test set: acc=94.70%, loss=0.1901
# Training: lr=0.001, arhitecture=[200, 40]
# On untrained model, test set: acc=7.98, loss=2.3088
# Epoch 1/30, train set: loss=1.8963
# Epoch 1/30, test set: acc=69.23%, loss=1.3662
# Epoch 2/30, train set: loss=1.0499
# Epoch 2/30, test set: acc=83.60%, loss=0.7998
# Epoch 3/30, train set: loss=0.6877
# Epoch 3/30, test set: acc=86.96%, loss=0.5759
# Epoch 4/30, train set: loss=0.5338
# Epoch 4/30, test set: acc=88.48%, loss=0.4724
# Epoch 5/30, train set: loss=0.4562
# Epoch 5/30, test set: acc=89.17%, loss=0.4164
# Epoch 6/30, train set: loss=0.4112
# Epoch 6/30, test set: acc=89.71%, loss=0.3820
# Epoch 7/30, train set: loss=0.3817
# Epoch 7/30, test set: acc=90.07%, loss=0.3587
# Epoch 8/30, train set: loss=0.3606
# Epoch 8/30, test set: acc=90.40%, loss=0.3413
# Epoch 9/30, train set: loss=0.3443
# Epoch 9/30, test set: acc=90.75%, loss=0.3282
# Epoch 10/30, train set: loss=0.3312
# Epoch 10/30, test set: acc=91.06%, loss=0.3169
# Epoch 11/30, train set: loss=0.3203
# Epoch 11/30, test set: acc=91.24%, loss=0.3073
# Epoch 12/30, train set: loss=0.3109
# Epoch 12/30, test set: acc=91.52%, loss=0.2991
# Epoch 13/30, train set: loss=0.3028
# Epoch 13/30, test set: acc=91.63%, loss=0.2921
# Epoch 14/30, train set: loss=0.2954
# Epoch 14/30, test set: acc=91.98%, loss=0.2855
# Epoch 15/30, train set: loss=0.2889
# Epoch 15/30, test set: acc=92.11%, loss=0.2802
# Epoch 16/30, train set: loss=0.2828
# Epoch 16/30, test set: acc=92.36%, loss=0.2748
# Epoch 17/30, train set: loss=0.2773
# Epoch 17/30, test set: acc=92.47%, loss=0.2701
# Epoch 18/30, train set: loss=0.2722
# Epoch 18/30, test set: acc=92.57%, loss=0.2648
# Epoch 19/30, train set: loss=0.2673
# Epoch 19/30, test set: acc=92.66%, loss=0.2605
# Epoch 20/30, train set: loss=0.2628
# Epoch 20/30, test set: acc=92.75%, loss=0.2570
# Epoch 21/30, train set: loss=0.2585
# Epoch 21/30, test set: acc=92.83%, loss=0.2527
# Epoch 22/30, train set: loss=0.2544
# Epoch 22/30, test set: acc=92.96%, loss=0.2489
# Epoch 23/30, train set: loss=0.2505
# Epoch 23/30, test set: acc=93.07%, loss=0.2451
# Epoch 24/30, train set: loss=0.2466
# Epoch 24/30, test set: acc=93.19%, loss=0.2421
# Epoch 25/30, train set: loss=0.2431
# Epoch 25/30, test set: acc=93.24%, loss=0.2388
# Epoch 26/30, train set: loss=0.2395
# Epoch 26/30, test set: acc=93.37%, loss=0.2359
# Epoch 27/30, train set: loss=0.2360
# Epoch 27/30, test set: acc=93.53%, loss=0.2325
# Epoch 28/30, train set: loss=0.2327
# Epoch 28/30, test set: acc=93.57%, loss=0.2296
# Epoch 29/30, train set: loss=0.2294
# Epoch 29/30, test set: acc=93.59%, loss=0.2266
# Epoch 30/30, train set: loss=0.2262
# Epoch 30/30, test set: acc=93.82%, loss=0.2235
# Training: lr=0.0001, arhitecture=[100, 40, 20]
# On untrained model, test set: acc=7.62, loss=2.3108
# Epoch 1/30, train set: loss=2.3013
# Epoch 1/30, test set: acc=11.97%, loss=2.2896
# Epoch 2/30, train set: loss=2.2798
# Epoch 2/30, test set: acc=15.12%, loss=2.2678
# Epoch 3/30, train set: loss=2.2573
# Epoch 3/30, test set: acc=20.61%, loss=2.2440
# Epoch 4/30, train set: loss=2.2319
# Epoch 4/30, test set: acc=30.10%, loss=2.2165
# Epoch 5/30, train set: loss=2.2020
# Epoch 5/30, test set: acc=42.62%, loss=2.1833
# Epoch 6/30, train set: loss=2.1654
# Epoch 6/30, test set: acc=46.90%, loss=2.1424
# Epoch 7/30, train set: loss=2.1205
# Epoch 7/30, test set: acc=47.99%, loss=2.0924
# Epoch 8/30, train set: loss=2.0665
# Epoch 8/30, test set: acc=47.84%, loss=2.0333
# Epoch 9/30, train set: loss=2.0042
# Epoch 9/30, test set: acc=48.28%, loss=1.9670
# Epoch 10/30, train set: loss=1.9358
# Epoch 10/30, test set: acc=48.89%, loss=1.8957
# Epoch 11/30, train set: loss=1.8635
# Epoch 11/30, test set: acc=50.55%, loss=1.8216
# Epoch 12/30, train set: loss=1.7886
# Epoch 12/30, test set: acc=52.79%, loss=1.7455
# Epoch 13/30, train set: loss=1.7121
# Epoch 13/30, test set: acc=55.73%, loss=1.6684
# Epoch 14/30, train set: loss=1.6351
# Epoch 14/30, test set: acc=58.84%, loss=1.5917
# Epoch 15/30, train set: loss=1.5593
# Epoch 15/30, test set: acc=61.34%, loss=1.5172
# Epoch 16/30, train set: loss=1.4865
# Epoch 16/30, test set: acc=63.68%, loss=1.4460
# Epoch 17/30, train set: loss=1.4173
# Epoch 17/30, test set: acc=65.90%, loss=1.3786
# Epoch 18/30, train set: loss=1.3519
# Epoch 18/30, test set: acc=67.68%, loss=1.3148
# Epoch 19/30, train set: loss=1.2904
# Epoch 19/30, test set: acc=69.80%, loss=1.2546
# Epoch 20/30, train set: loss=1.2326
# Epoch 20/30, test set: acc=71.36%, loss=1.1980
# Epoch 21/30, train set: loss=1.1786
# Epoch 21/30, test set: acc=72.83%, loss=1.1454
# Epoch 22/30, train set: loss=1.1288
# Epoch 22/30, test set: acc=74.00%, loss=1.0969
# Epoch 23/30, train set: loss=1.0830
# Epoch 23/30, test set: acc=75.01%, loss=1.0525
# Epoch 24/30, train set: loss=1.0413
# Epoch 24/30, test set: acc=76.18%, loss=1.0121
# Epoch 25/30, train set: loss=1.0033
# Epoch 25/30, test set: acc=77.09%, loss=0.9753
# Epoch 26/30, train set: loss=0.9688
# Epoch 26/30, test set: acc=77.64%, loss=0.9417
# Epoch 27/30, train set: loss=0.9373
# Epoch 27/30, test set: acc=78.31%, loss=0.9112
# Epoch 28/30, train set: loss=0.9084
# Epoch 28/30, test set: acc=79.00%, loss=0.8830
# Epoch 29/30, train set: loss=0.8818
# Epoch 29/30, test set: acc=79.43%, loss=0.8571
# Epoch 30/30, train set: loss=0.8572
# Epoch 30/30, test set: acc=80.04%, loss=0.8331
# Training: lr=0.0001, arhitecture=[200, 40]
# On untrained model, test set: acc=5.72, loss=2.3137
# Epoch 1/30, train set: loss=2.2783
# Epoch 1/30, test set: acc=34.03%, loss=2.2404
# Epoch 2/30, train set: loss=2.2059
# Epoch 2/30, test set: acc=52.64%, loss=2.1663
# Epoch 3/30, train set: loss=2.1301
# Epoch 3/30, test set: acc=60.17%, loss=2.0851
# Epoch 4/30, train set: loss=2.0446
# Epoch 4/30, test set: acc=62.47%, loss=1.9918
# Epoch 5/30, train set: loss=1.9458
# Epoch 5/30, test set: acc=63.55%, loss=1.8847
# Epoch 6/30, train set: loss=1.8344
# Epoch 6/30, test set: acc=63.84%, loss=1.7671
# Epoch 7/30, train set: loss=1.7156
# Epoch 7/30, test set: acc=64.16%, loss=1.6459
# Epoch 8/30, train set: loss=1.5967
# Epoch 8/30, test set: acc=64.88%, loss=1.5288
# Epoch 9/30, train set: loss=1.4841
# Epoch 9/30, test set: acc=66.13%, loss=1.4207
# Epoch 10/30, train set: loss=1.3814
# Epoch 10/30, test set: acc=67.87%, loss=1.3238
# Epoch 11/30, train set: loss=1.2898
# Epoch 11/30, test set: acc=70.02%, loss=1.2378
# Epoch 12/30, train set: loss=1.2088
# Epoch 12/30, test set: acc=72.00%, loss=1.1619
# Epoch 13/30, train set: loss=1.1370
# Epoch 13/30, test set: acc=74.04%, loss=1.0945
# Epoch 14/30, train set: loss=1.0733
# Epoch 14/30, test set: acc=76.13%, loss=1.0344
# Epoch 15/30, train set: loss=1.0163
# Epoch 15/30, test set: acc=77.65%, loss=0.9804
# Epoch 16/30, train set: loss=0.9651
# Epoch 16/30, test set: acc=79.14%, loss=0.9317
# Epoch 17/30, train set: loss=0.9189
# Epoch 17/30, test set: acc=80.41%, loss=0.8876
# Epoch 18/30, train set: loss=0.8770
# Epoch 18/30, test set: acc=81.21%, loss=0.8476
# Epoch 19/30, train set: loss=0.8391
# Epoch 19/30, test set: acc=82.06%, loss=0.8112
# Epoch 20/30, train set: loss=0.8046
# Epoch 20/30, test set: acc=82.85%, loss=0.7780
# Epoch 21/30, train set: loss=0.7731
# Epoch 21/30, test set: acc=83.60%, loss=0.7476
# Epoch 22/30, train set: loss=0.7443
# Epoch 22/30, test set: acc=84.23%, loss=0.7199
# Epoch 23/30, train set: loss=0.7181
# Epoch 23/30, test set: acc=84.64%, loss=0.6946
# Epoch 24/30, train set: loss=0.6940
# Epoch 24/30, test set: acc=85.00%, loss=0.6713
# Epoch 25/30, train set: loss=0.6720
# Epoch 25/30, test set: acc=85.27%, loss=0.6501
# Epoch 26/30, train set: loss=0.6518
# Epoch 26/30, test set: acc=85.62%, loss=0.6305
# Epoch 27/30, train set: loss=0.6332
# Epoch 27/30, test set: acc=85.90%, loss=0.6125
# Epoch 28/30, train set: loss=0.6161
# Epoch 28/30, test set: acc=86.16%, loss=0.5959
# Epoch 29/30, train set: loss=0.6003
# Epoch 29/30, test set: acc=86.40%, loss=0.5806
# Epoch 30/30, train set: loss=0.5857
# Epoch 30/30, test set: acc=86.63%, loss=0.5665

# %%
print(max_accuracy)
print(best_performing_params)
